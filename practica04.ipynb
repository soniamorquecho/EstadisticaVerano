# %% [markdown]
# <a href="https://colab.research.google.com/github/soniamorquecho/EstadisticaVerano/blob/main/practica04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df= pd.read_csv("https://raw.githubusercontent.com/soniamorquecho/EstadisticaVerano/refs/heads/main/Hipertension_Arterial_Mexico.csv")
df
# Out:
#             FOLIO_I  sexo  edad  concentracion_hemoglobina  \
# 0     2022_01001004     2    41                       14.2
# 1     2022_01001009     2    65                       14.1
# 2     2022_01001012     2    68                       14.2
# 3     2022_01001013     1    35                       15.7
# 4     2022_01001015     2    65                       12.7
# ...             ...   ...   ...                        ...
# 4358  2022_32056019     2    62                       14.2
# 4359  2022_32056024     1    39                       14.2
# 4360  2022_32056026     2    69                       15.9
# 4361  2022_32056029     1    67                       17.6
# 4362  2022_32056030     2    56                       14.2
#
#       temperatura_ambiente  valor_acido_urico  valor_albumina  \
# 0                       22                4.8             4.0
# 1                        9                4.4             3.8
# 2                       22                4.8             4.0
# 3                       11                6.5             4.1
# 4                        7                4.2             4.2
# ...                    ...                ...             ...
# 4358                    22                4.8             4.0
# 4359                    22                4.8             4.0
# 4360                    11                2.9             1.9
# 4361                    14                5.5             4.0
# 4362                    22                4.8             4.0
#
#       valor_colesterol_hdl  valor_colesterol_ldl  valor_colesterol_total  ...  \
# 0                       34                  86.0                     139  ...
# 1                       73                 130.0                     252  ...
# 2                       34                  86.0                     139  ...
# 3                       49                 107.0                     203  ...
# 4                       41                  76.0                     145  ...
# ...                    ...                   ...                     ...  ...
# 4358                    34                  86.0                     139  ...
# 4359                    34                  86.0                     139  ...
# 4360                    21                  44.0                      74  ...
# 4361                    44                  96.0                     171  ...
# 4362                    34                  86.0                     139  ...
#
#       segundamedicion_peso  segundamedicion_estatura  distancia_rodilla_talon  \
# 0                    64.70                     154.0                     48.5
# 1                    96.75                     152.2                     44.5
# 2                    68.70                     144.8                     42.3
# 3                    64.70                     154.0                     48.5
# 4                    97.15                     161.3                     49.6
# ...                    ...                       ...                      ...
# 4358                 64.25                     160.5                     51.1
# 4359                 64.70                     154.0                     48.5
# 4360                 71.20                     148.6                     47.2
# 4361                 68.20                     167.7                     51.5
# 4362                 64.70                     154.0                     48.5
#
#       circunferencia_de_la_pantorrilla  segundamedicion_cintura  \
# 0                                 33.5                      0.0
# 1                                 41.1                    113.7
# 2                                 37.8                    103.7
# 3                                 33.5                      0.0
# 4                                 42.0                    118.9
# ...                                ...                      ...
# 4358                              34.5                     77.8
# 4359                              33.5                      0.0
# 4360                              38.0                      0.0
# 4361                              36.5                     96.4
# 4362                              33.5                      0.0
#
#       tension_arterial  sueno_horas  masa_corporal  actividad_total  \
# 0                  107            4      32.889389              120
# 1                  104            2       1.000000              240
# 2                  105            1       1.000000              480
# 3                  117            5      26.265339              275
# 4                  123            2       1.000000              255
# ...                ...          ...            ...              ...
# 4358               125            4       1.000000              280
# 4359               130            4      19.193721              780
# 4360               147            4       1.000000              300
# 4361               108            2       1.000000              240
# 4362               100            4      25.600777              300
#
#       riesgo_hipertension
# 0                       1
# 1                       0
# 2                       0
# 3                       1
# 4                       0
# ...                   ...
# 4358                    0
# 4359                    0
# 4360                    0
# 4361                    0
# 4362                    0
#
# [4363 rows x 36 columns]

# %%
df= df.drop(columns=["FOLIO_I"])
df
# Out:
#       sexo  edad  concentracion_hemoglobina  temperatura_ambiente  \
# 0        2    41                       14.2                    22
# 1        2    65                       14.1                     9
# 2        2    68                       14.2                    22
# 3        1    35                       15.7                    11
# 4        2    65                       12.7                     7
# ...    ...   ...                        ...                   ...
# 4358     2    62                       14.2                    22
# 4359     1    39                       14.2                    22
# 4360     2    69                       15.9                    11
# 4361     1    67                       17.6                    14
# 4362     2    56                       14.2                    22
#
#       valor_acido_urico  valor_albumina  valor_colesterol_hdl  \
# 0                   4.8             4.0                    34
# 1                   4.4             3.8                    73
# 2                   4.8             4.0                    34
# 3                   6.5             4.1                    49
# 4                   4.2             4.2                    41
# ...                 ...             ...                   ...
# 4358                4.8             4.0                    34
# 4359                4.8             4.0                    34
# 4360                2.9             1.9                    21
# 4361                5.5             4.0                    44
# 4362                4.8             4.0                    34
#
#       valor_colesterol_ldl  valor_colesterol_total  valor_creatina  ...  \
# 0                     86.0                     139            0.58  ...
# 1                    130.0                     252            0.62  ...
# 2                     86.0                     139            0.58  ...
# 3                    107.0                     203            0.91  ...
# 4                     76.0                     145            0.71  ...
# ...                    ...                     ...             ...  ...
# 4358                  86.0                     139            0.58  ...
# 4359                  86.0                     139            0.58  ...
# 4360                  44.0                      74            0.34  ...
# 4361                  96.0                     171            0.80  ...
# 4362                  86.0                     139            0.58  ...
#
#       segundamedicion_peso  segundamedicion_estatura  distancia_rodilla_talon  \
# 0                    64.70                     154.0                     48.5
# 1                    96.75                     152.2                     44.5
# 2                    68.70                     144.8                     42.3
# 3                    64.70                     154.0                     48.5
# 4                    97.15                     161.3                     49.6
# ...                    ...                       ...                      ...
# 4358                 64.25                     160.5                     51.1
# 4359                 64.70                     154.0                     48.5
# 4360                 71.20                     148.6                     47.2
# 4361                 68.20                     167.7                     51.5
# 4362                 64.70                     154.0                     48.5
#
#       circunferencia_de_la_pantorrilla  segundamedicion_cintura  \
# 0                                 33.5                      0.0
# 1                                 41.1                    113.7
# 2                                 37.8                    103.7
# 3                                 33.5                      0.0
# 4                                 42.0                    118.9
# ...                                ...                      ...
# 4358                              34.5                     77.8
# 4359                              33.5                      0.0
# 4360                              38.0                      0.0
# 4361                              36.5                     96.4
# 4362                              33.5                      0.0
#
#       tension_arterial  sueno_horas  masa_corporal  actividad_total  \
# 0                  107            4      32.889389              120
# 1                  104            2       1.000000              240
# 2                  105            1       1.000000              480
# 3                  117            5      26.265339              275
# 4                  123            2       1.000000              255
# ...                ...          ...            ...              ...
# 4358               125            4       1.000000              280
# 4359               130            4      19.193721              780
# 4360               147            4       1.000000              300
# 4361               108            2       1.000000              240
# 4362               100            4      25.600777              300
#
#       riesgo_hipertension
# 0                       1
# 1                       0
# 2                       0
# 3                       1
# 4                       0
# ...                   ...
# 4358                    0
# 4359                    0
# 4360                    0
# 4361                    0
# 4362                    0
#
# [4363 rows x 35 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

matriz_de_correlacion= df.corr()

plt.figure(figsize=(20,25), dpi= 100)

sns.heatmap(
    matriz_de_correlacion, #lo que va a graficar
    annot= True, #se muestran los valores en las celdas
    fmt= "0.2f", #0.2f significa "dos decimales"
    cmap= "coolwarm", #paleta de colores
    square= True, #forzar cuadrados
    linewidths= 0.5, #grosor de lineas
    cbar_kws= {"shrink":0.5}, #tamaño barra lateral
    center= 0,
    )

plt.title("Mapa de color para matriz de correlacion", fontsize=20)
plt.xticks(rotation= 45, ha= "right")
plt.yticks(rotation= 0)
# Out:
# (array([ 0.5,  1.5,  2.5,  3.5,  4.5,  5.5,  6.5,  7.5,  8.5,  9.5, 10.5,
#         11.5, 12.5, 13.5, 14.5, 15.5, 16.5, 17.5, 18.5, 19.5, 20.5, 21.5,
#         22.5, 23.5, 24.5, 25.5, 26.5, 27.5, 28.5, 29.5, 30.5, 31.5, 32.5,
#         33.5, 34.5]),
#  [Text(0, 0.5, 'sexo'),
#   Text(0, 1.5, 'edad'),
#   Text(0, 2.5, 'concentracion_hemoglobina'),
#   Text(0, 3.5, 'temperatura_ambiente'),
#   Text(0, 4.5, 'valor_acido_urico'),
#   Text(0, 5.5, 'valor_albumina'),
#   Text(0, 6.5, 'valor_colesterol_hdl'),
#   Text(0, 7.5, 'valor_colesterol_ldl'),
#   Text(0, 8.5, 'valor_colesterol_total'),
#   Text(0, 9.5, 'valor_creatina'),
#   Text(0, 10.5, 'resultado_glucosa'),
#   Text(0, 11.5, 'valor_insulina'),
#   Text(0, 12.5, 'valor_trigliceridos'),
#   Text(0, 13.5, 'resultado_glucosa_promedio'),
#   Text(0, 14.5, 'valor_hemoglobina_glucosilada'),
#   Text(0, 15.5, 'valor_ferritina'),
#   Text(0, 16.5, 'valor_folato'),
#   Text(0, 17.5, 'valor_homocisteina'),
#   Text(0, 18.5, 'valor_proteinac_reactiva'),
#   Text(0, 19.5, 'valor_transferrina'),
#   Text(0, 20.5, 'valor_vitamina_bdoce'),
#   Text(0, 21.5, 'valor_vitamina_d'),
#   Text(0, 22.5, 'peso'),
#   Text(0, 23.5, 'estatura'),
#   Text(0, 24.5, 'medida_cintura'),
#   Text(0, 25.5, 'segundamedicion_peso'),
#   Text(0, 26.5, 'segundamedicion_estatura'),
#   Text(0, 27.5, 'distancia_rodilla_talon'),
#   Text(0, 28.5, 'circunferencia_de_la_pantorrilla'),
#   Text(0, 29.5, 'segundamedicion_cintura'),
#   Text(0, 30.5, 'tension_arterial'),
#   Text(0, 31.5, 'sueno_horas'),
#   Text(0, 32.5, 'masa_corporal'),
#   Text(0, 33.5, 'actividad_total'),
#   Text(0, 34.5, 'riesgo_hipertension')])

# %%
df["masa_corporal"].hist(bins=50)
# Out:
# <Axes: >

# %%
df["edad"].hist(bins=50)
# Out:
# <Axes: >

# %%
df["tension_arterial"].hist(bins=50)
# Out:
# <Axes: >

# %%
df=df[df["tension_arterial"]!=0]
df
# Out:
#       sexo  edad  concentracion_hemoglobina  temperatura_ambiente  \
# 0        2    41                       14.2                    22
# 1        2    65                       14.1                     9
# 2        2    68                       14.2                    22
# 3        1    35                       15.7                    11
# 4        2    65                       12.7                     7
# ...    ...   ...                        ...                   ...
# 4358     2    62                       14.2                    22
# 4359     1    39                       14.2                    22
# 4360     2    69                       15.9                    11
# 4361     1    67                       17.6                    14
# 4362     2    56                       14.2                    22
#
#       valor_acido_urico  valor_albumina  valor_colesterol_hdl  \
# 0                   4.8             4.0                    34
# 1                   4.4             3.8                    73
# 2                   4.8             4.0                    34
# 3                   6.5             4.1                    49
# 4                   4.2             4.2                    41
# ...                 ...             ...                   ...
# 4358                4.8             4.0                    34
# 4359                4.8             4.0                    34
# 4360                2.9             1.9                    21
# 4361                5.5             4.0                    44
# 4362                4.8             4.0                    34
#
#       valor_colesterol_ldl  valor_colesterol_total  valor_creatina  ...  \
# 0                     86.0                     139            0.58  ...
# 1                    130.0                     252            0.62  ...
# 2                     86.0                     139            0.58  ...
# 3                    107.0                     203            0.91  ...
# 4                     76.0                     145            0.71  ...
# ...                    ...                     ...             ...  ...
# 4358                  86.0                     139            0.58  ...
# 4359                  86.0                     139            0.58  ...
# 4360                  44.0                      74            0.34  ...
# 4361                  96.0                     171            0.80  ...
# 4362                  86.0                     139            0.58  ...
#
#       segundamedicion_peso  segundamedicion_estatura  distancia_rodilla_talon  \
# 0                    64.70                     154.0                     48.5
# 1                    96.75                     152.2                     44.5
# 2                    68.70                     144.8                     42.3
# 3                    64.70                     154.0                     48.5
# 4                    97.15                     161.3                     49.6
# ...                    ...                       ...                      ...
# 4358                 64.25                     160.5                     51.1
# 4359                 64.70                     154.0                     48.5
# 4360                 71.20                     148.6                     47.2
# 4361                 68.20                     167.7                     51.5
# 4362                 64.70                     154.0                     48.5
#
#       circunferencia_de_la_pantorrilla  segundamedicion_cintura  \
# 0                                 33.5                      0.0
# 1                                 41.1                    113.7
# 2                                 37.8                    103.7
# 3                                 33.5                      0.0
# 4                                 42.0                    118.9
# ...                                ...                      ...
# 4358                              34.5                     77.8
# 4359                              33.5                      0.0
# 4360                              38.0                      0.0
# 4361                              36.5                     96.4
# 4362                              33.5                      0.0
#
#       tension_arterial  sueno_horas  masa_corporal  actividad_total  \
# 0                  107            4      32.889389              120
# 1                  104            2       1.000000              240
# 2                  105            1       1.000000              480
# 3                  117            5      26.265339              275
# 4                  123            2       1.000000              255
# ...                ...          ...            ...              ...
# 4358               125            4       1.000000              280
# 4359               130            4      19.193721              780
# 4360               147            4       1.000000              300
# 4361               108            2       1.000000              240
# 4362               100            4      25.600777              300
#
#       riesgo_hipertension
# 0                       1
# 1                       0
# 2                       0
# 3                       1
# 4                       0
# ...                   ...
# 4358                    0
# 4359                    0
# 4360                    0
# 4361                    0
# 4362                    0
#
# [4334 rows x 35 columns]

# %%
df["tension_arterial"].hist(bins=50)
# Out:
# <Axes: >

# %%
x=df["edad"]
y=df["tension_arterial"]

#2 Realice un diagrama de dispersion para estos datos
import matplotlib.pyplot as plt

plt.figure(figsize = (6,3), dpi=100)
plt.scatter(x, y, label = "tension_arterial", color = "pink")
plt.xlabel("edad") #nombrar eje x
plt.ylabel("tension_arterial") #nombrar eje y
plt.gca().spines[["top","right"]].set_visible(False)

#3 ¿Los datos soportan la suposicion de linealidad?
#Si

#4 Calcule el coeficiente de correlacion e interprete el resultado
from scipy.stats import pearsonr
r,_= pearsonr(x,y)
print(f"Coeficiente de correlacion: {r: 0.4f}/n")

#6. Obtenga la recta de regresion ajustada y grafiquelo sobre el grafico  de dispersion
import statsmodels.api as sm
x_constante = sm.add_constant(x)
modelo= sm.OLS(y, x_constante).fit()

yc= modelo.predict(x_constante)

plt.plot(x, yc, color= "gray", linestyle= "--")

#5 Calcule el coeficiente de determinacion  e interprete el resultado
from sklearn.metrics import r2_score #recomendada
r2= r2_score(y,yc)
print(f"Coeficiente de determinacion: {r2: 0.4f}/n")

#7. Obtenga un intervalo de confiamza del 95% par la pendiente de la recta de regresion ajustada (b1)
nivel_de_confianza= 0.95
intervalo_de_confianza = modelo.conf_int(alpha = 1 - nivel_de_confianza)
intervalo_de_confianza_b1= intervalo_de_confianza.iloc[1]
print(f"Intervalo de confianza para b1 de {nivel_de_confianza: 0.0%}")
print(f"{intervalo_de_confianza_b1[0]: 0.4f}<b1< {intervalo_de_confianza_b1[1]:0.4f}/n")

#8. Calcule los residuales
residuales=modelo.resid
plt.figure()
plt.scatter(x, residuales, color= "orange")
plt.xlabel("Edad")
plt.ylabel("Tension arterial")
plt.axhline(y= 0, color= "gray", linestyle= "--")
plt.gca().spines[["top", "right"]].set_visible(False)

#9. Realice la prueba de Shapiro para los residuales
from scipy.stats import shapiro
_, valor_p_sh= shapiro(residuales)
print(f"valor-p de Shapiro: {valor_p_sh: 0.4f}/n")
#Se acepta la hipotesis alternativa, no hay normalidad

#10. Realice la prueba de Breusch Pagan
from statsmodels.stats.api import het_breuschpagan
_, valor_p_bp, _, _= het_breuschpagan(residuales, x_constante)
print(f"valor_p de Breusch-Pagan: {valor_p_bp: 0.4f}/n")
#Se rechaza la hipotesis nula, existe heteroscedasticidad

#11. Utiliza la recta de regresion para interpolar dos valores e interpolar uno
print(f"para x= 2, y={modelo.predict([1,2])}")
print(f"para x= 3, y={modelo.predict([1, 3])}")
print(f"para x= 5, y={modelo.predict([1, 5])}/n")

#12. Realice una tabla ANOVA e interprete el resultado
from statsmodels.formula.api import ols
#Y ~ X
modelo_lineal = ols("tension_arterial~edad",data=df).fit()
tabla_anova= sm.stats.anova_lm(modelo_lineal)
tabla_anova
#Se acepta la hipotesis nula, B1=0
# Out:
# Coeficiente de correlacion:  0.3855/n
# Coeficiente de determinacion:  0.1486/n
# Intervalo de confianza para b1 de  95%
#  0.5025<b1< 0.5797/n
# valor-p de Shapiro:  0.0000/n
# valor_p de Breusch-Pagan:  0.0000/n
# para x= 2, y=[100.03859087]
# para x= 3, y=[100.57969321]
# para x= 5, y=[101.6618979]/n
#               df        sum_sq        mean_sq           F         PR(>F)
# edad         1.0  2.648644e+05  264864.431816  755.969001  1.544912e-153
# Residual  4332.0  1.517777e+06     350.364144         NaN            NaN

# %%
#CONCLUSION

#Linealidad incierta
#Relacion baja
#No hay homoscedasticidad
#Existe relacion entre las variables

# %%
df["segundamedicion_cintura"].hist(bins=50)
# Out:
# <Axes: >

# %%
df=df[df["segundamedicion_cintura"]!=0]
df
# Out:
#       sexo  edad  concentracion_hemoglobina  temperatura_ambiente  \
# 1        2    65                       14.1                     9
# 2        2    68                       14.2                    22
# 4        2    65                       12.7                     7
# 9        2    62                       14.5                     9
# 14       2    60                       13.6                    19
# ...    ...   ...                        ...                   ...
# 4350     1    60                       14.2                    22
# 4356     2    61                       14.2                    22
# 4357     2    74                       14.6                    12
# 4358     2    62                       14.2                    22
# 4361     1    67                       17.6                    14
#
#       valor_acido_urico  valor_albumina  valor_colesterol_hdl  \
# 1                   4.4             3.8                    73
# 2                   4.8             4.0                    34
# 4                   4.2             4.2                    41
# 9                   4.4             3.8                    44
# 14                  4.1             3.4                    48
# ...                 ...             ...                   ...
# 4350                4.8             4.0                    34
# 4356                4.8             4.0                    34
# 4357                6.3             3.8                    50
# 4358                4.8             4.0                    34
# 4361                5.5             4.0                    44
#
#       valor_colesterol_ldl  valor_colesterol_total  valor_creatina  ...  \
# 1                    130.0                     252            0.62  ...
# 2                     86.0                     139            0.58  ...
# 4                     76.0                     145            0.71  ...
# 9                    133.0                     236            0.66  ...
# 14                   142.0                     229            0.49  ...
# ...                    ...                     ...             ...  ...
# 4350                  86.0                     139            0.58  ...
# 4356                  86.0                     139            0.58  ...
# 4357                 108.9                     208            0.59  ...
# 4358                  86.0                     139            0.58  ...
# 4361                  96.0                     171            0.80  ...
#
#       segundamedicion_peso  segundamedicion_estatura  distancia_rodilla_talon  \
# 1                    96.75                     152.2                     44.5
# 2                    68.70                     144.8                     42.3
# 4                    97.15                     161.3                     49.6
# 9                   102.45                     134.2                     48.2
# 14                   64.70                     153.4                     46.7
# ...                    ...                       ...                      ...
# 4350                 80.80                     172.5                     54.2
# 4356                 97.15                     170.0                     53.5
# 4357                 63.65                     159.8                     50.7
# 4358                 64.25                     160.5                     51.1
# 4361                 68.20                     167.7                     51.5
#
#       circunferencia_de_la_pantorrilla  segundamedicion_cintura  \
# 1                                 41.1                    113.7
# 2                                 37.8                    103.7
# 4                                 42.0                    118.9
# 9                                 39.6                    134.2
# 14                                35.5                     92.4
# ...                                ...                      ...
# 4350                              37.5                    100.9
# 4356                              45.5                    119.0
# 4357                              32.9                     88.2
# 4358                              34.5                     77.8
# 4361                              36.5                     96.4
#
#       tension_arterial  sueno_horas  masa_corporal  actividad_total  \
# 1                  104            2            1.0              240
# 2                  105            1            1.0              480
# 4                  123            2            1.0              255
# 9                  111            2            1.0              150
# 14                 119            4            1.0               70
# ...                ...          ...            ...              ...
# 4350               193            3            1.0              780
# 4356               185            3            1.0              450
# 4357               137            3            1.0              930
# 4358               125            4            1.0              280
# 4361               108            2            1.0              240
#
#       riesgo_hipertension
# 1                       0
# 2                       0
# 4                       0
# 9                       1
# 14                      1
# ...                   ...
# 4350                    0
# 4356                    0
# 4357                    0
# 4358                    0
# 4361                    0
#
# [864 rows x 35 columns]

# %%
df["segundamedicion_cintura"].hist(bins=50)
# Out:
# <Axes: >

# %%
x=df[["edad","segundamedicion_cintura"]]
y=df["tension_arterial"]

#2
import matplotlib.pyplot as plt

#6. Obtenga la recta de regresion ajustada y grafiquelo sobre el grafico  de dispersion
import statsmodels.api as sm
x_constante = sm.add_constant(x)
modelo= sm.OLS(y, x_constante).fit()

yc= modelo.predict(x_constante)


#5 Calcule el coeficiente de determinacion  e interprete el resultado
from sklearn.metrics import r2_score #recomendada
r2= r2_score(y,yc)
print(f"Coeficiente de determinacion: {r2: 0.4f}/n")

#7. Obtenga un intervalo de confiamza del 95% par la pendiente de la recta de regresion ajustada (b1)
nivel_de_confianza= 0.95
intervalo_de_confianza = modelo.conf_int(alpha = 1 - nivel_de_confianza)
intervalo_de_confianza_b1= intervalo_de_confianza.iloc[1]
print(f"Intervalo de confianza para b1 de {nivel_de_confianza: 0.0%}")
print(f"{intervalo_de_confianza_b1[0]: 0.4f}<b1< {intervalo_de_confianza_b1[1]:0.4f}/n")

#8. Calcule los residuales
residuales=modelo.resid
plt.figure()
plt.scatter(y, yc, color= "orange")
plt.xlabel("Edad")
plt.ylabel("Tension arterial")
plt.axhline(y= 0, color= "gray", linestyle= "--")
plt.gca().spines[["top", "right"]].set_visible(False)

#9. Realice la prueba de Shapiro para los residuales
from scipy.stats import shapiro
_, valor_p_sh= shapiro(residuales)
print(f"valor-p de Shapiro: {valor_p_sh: 0.4f}/n")
#Se acepta la hipotesis alternativa, no hay normalidad

#10. Realice la prueba de Breusch Pagan
from statsmodels.stats.api import het_breuschpagan
_, valor_p_bp, _, _= het_breuschpagan(residuales, x_constante)
print(f"valor_p de Breusch-Pagan: {valor_p_bp: 0.4f}/n")
#Se rechaza la hipotesis nula, existe heteroscedasticidad

#11. Utiliza la recta de regresion para interpolar dos valores e interpolar uno
#print(f"para x= 2, y={modelo.predict([1,2])}")
#print(f"para x= 3, y={modelo.predict([1, 3])}")
#print(f"para x= 5, y={modelo.predict([1, 5])}/n")

#12. Realice una tabla ANOVA e interprete el resultado
from statsmodels.formula.api import ols
#Y ~ X
modelo_lineal = ols("tension_arterial~edad+segundamedicion_cintura",data=df).fit()
tabla_anova= sm.stats.anova_lm(modelo_lineal)
tabla_anova
#Se acepta la hipotesis nula, B1=0, ho hay relacion
#Se acepta la hipotesis alternativa, B2 diferente de 0, si hay relacion
# Out:
# Coeficiente de determinacion:  0.0229/n
# Intervalo de confianza para b1 de  95%
# -0.0969<b1< 0.4131/n
# valor-p de Shapiro:  0.0000/n
# valor_p de Breusch-Pagan:  0.7883/n
#                             df         sum_sq      mean_sq          F  \
# edad                       1.0     509.779865   509.779865   1.051053
# segundamedicion_cintura    1.0    9272.922904  9272.922904  19.118713
# Residual                 861.0  417600.629407   485.018153        NaN
#
#                            PR(>F)
# edad                     0.305553
# segundamedicion_cintura  0.000014
# Residual                      NaN
